# %% [markdown]
# # 1. write a function which will try to find out len of a string without using an inbuilt len function

# %%
l =input("Enter a string : ")
# Out:
# Enter a string : Remya R S

# %%
def length_str(l):
    count = 0
    for i in l:
        count = count +1
    return count

# %%
length_str(l)
# Out:
# 9

# %% [markdown]
# # 2. write a function which  will be able to print an index of list element without using an index function

# %%
l=[3,4,5,7,0]

# %%
ele = int(input("Enter element whose index number is to be found : "))
# Out:
# Enter element whose index number is to be found : 5

# %%
def index_num(l,ele):
    count = 0
    for i in l:
        if l[count]==ele:
            break
        else:
            count = count + 1
    return count

# %%
index_num(l,ele)
# Out:
# 2

# %% [markdown]
# To print index of all elements:

# %%
def index_all(l):
    count = 0
    for i in l:
        print(f"index of {i} is : {count}")
        count = count + 1

# %%
index_all(l)
# Out:
# index of 3 is : 0
# index of 4 is : 1
# index of 5 is : 2
# index of 7 is : 3
# index of 0 is : 4

# %% [markdown]
# # 3. write a function which will be able to print an ip address of your system

# %%
import socket

# %%
def ip_address():
    ip = socket.gethostbyname(socket.gethostname())
    return ip

# %%
ip_address()
# Out:
# '192.168.1.40'

# %% [markdown]
# # 4. write a function which will shutdown your system

# %%
import os

# %%
#4. write a function which will shutdown your system
import os
os.system("shutdown /s /t 4")

# /s - shutdown
# /r - restart 
# /t 1 - timer

# %% [markdown]
# # 5. write a function which will take input as a list with any kind of numeric value and give an out as a multiplication of
# all the numeric data l = [3.5, 6.56, 4,5,"sudh" , "ineuron" , 'fsda bootcamp 2.0']

# %%
l = [3.5,6.56,4,5,"sudh" , "ineuron" , 'fsda bootcamp 2.0']

def num_mul():
    mul = 1
    for i in l:
        if (type(i)==int) or (type(i)==float):
            mul = mul * i
    return mul

num_mul()
# Out:
# 459.19999999999993

# %% [markdown]
# # 6. write a function which will be able to read all the mails

# %%
import smtplib
import time
import imaplib
import email
import traceback 
ORG_EMAIL = "@gmail.com" 
FROM_EMAIL = 'remya130989@gmail.com'
FROM_PWD = 'lyjvkpouykaabypa'
SMTP_SERVER = "imap.gmail.com" 
SMTP_PORT = 993
imaplib._MAXLINE = 400000000

def read_email_from_gmail():
    try:
        mail = imaplib.IMAP4_SSL(SMTP_SERVER)
        mail.login(FROM_EMAIL,FROM_PWD)
        mail.select('inbox')

        data = mail.search(None, 'ALL')
        mail_ids = data[1]
        id_list = mail_ids[0].split()   
        first_email_id = int(id_list[0])
        latest_email_id = int(id_list[-1])

        for i in range(latest_email_id,first_email_id, -1):
            data = mail.fetch(str(i), '(RFC822)' )
            for response_part in data:
                arr = response_part[0]
                if isinstance(arr, tuple):
                    msg = email.message_from_string(str(arr[1],'utf-8'))
                    email_subject = msg['subject']
                    email_from = msg['from']
                    print('From : ' + email_from + '\n')
                    print('Subject : ' + email_subject + '\n')

    except Exception as e:
        traceback.print_exc() 
        print(str(e))

read_email_from_gmail()
# Out:
# From : Google <no-reply@accounts.google.com>
#
# Subject : Security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Your Google Account was recovered successfully
#
# From : LinkedIn Job Alerts <jobalerts-noreply@linkedin.com>
#
# Subject : =?UTF-8?Q?1_new_job_for_=E2=80=9CLead_Data_Scientist=E2=80=9D?=
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Critical security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Critical security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Critical security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Critical security alert
#
# From : Google <no-reply@accounts.google.com>
#
# Subject : Critical security alert
#
# ...

# %% [markdown]
# # 7 . write a function which will be able to send a mail to anyone

# %%
import smtplib, ssl

# %%
port = 465  # For SSL
smtp_server = "smtp.gmail.com"
sender_email = "remya130989@gmail.com"  # Enter your address
receiver_email = "remyarish@gmail.com"  # Enter receiver address
password = 'abqckcdkklteignw'
message = """this is my message from python code in my live class"""

context = ssl.create_default_context()
with smtplib.SMTP_SSL(smtp_server, port, context=context) as server:
    server.login(sender_email, password)
    server.sendmail(sender_email, receiver_email, message)

# %% [markdown]
# # 8. write a function which will be able to read a doc/word file from your system

# %%
# !pip install docx2txt
import docx2txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
a = docx2txt.process('word_file.docx')
print(a)
# Out:
# Read the file
#
#
#
# Sample for task 8
